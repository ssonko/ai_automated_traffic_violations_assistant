# %%
import os
from dotenv import load_dotenv
from openai import OpenAI

load_dotenv(override=True, dotenv_path="../.env")
my_api_key = os.getenv("OPENAI_API_KEY")

client = OpenAI(api_key=my_api_key)

import base64

image_path1 = "data/invoice.png" 
image_path2 = "data/office_lease.png"

# %%
# Encode image as base64
with open(image_path1, "rb") as f:
    image1_base64 = base64.b64encode(f.read()).decode("utf-8")
# Code explanation:
    # Converts the binary data into a Base64-encoded string.
    # Base64 is a way of representing binary data (like images) using only text characters (A–Z, a–z, 0–9, +, /).
    # This is necessary because APIs (like OpenAI’s) can only transmit text, not raw binary files.

mime_type = "image/png"

#Request extraction from image
response = client.chat.completions.create(
    model="gpt-5-nano",
    messages=[
        {
            "role": "system",
            "content": "You extract and summarize information from invoices or forms."
        },
        {
            "role": "user",
            "content": [
                {"type": "text", "text": "Extract as many fields, such as Invoice from/Company, Invoice, Invoice information - number, data, due date etc, Invoice product list from this image as a JSON object:"},
                {"type": "image_url", "image_url": {"url": f"data:{mime_type};base64,{image1_base64}"}}
            ]
        }
    ],
)

print("🧾 Extracted Info from Image:\n")
print(response.choices[0].message.content)

# %%
# Encode image as base64
with open(image_path2, "rb") as f:
    image2_base64 = base64.b64encode(f.read()).decode("utf-8")

mime_type = "image/png"

# Request extraction from image
response = client.chat.completions.create(
    model="gpt-5-nano",
    messages=[
        {
            "role": "system",
            "content": "Extract and summarize information from this property for sale flyer."
        },
        {
            "role": "user",
            "content": [
                {"type": "text", "text": "Extract key fields from this image, such as property title, details etc as a JSON object:"},
                {"type": "image_url", "image_url": {"url": f"data:{mime_type};base64,{image2_base64}"}}
            ]
        }
    ],
)

print("🧾 Extracted Info from Image:\n")
print(response.choices[0].message.content)

# %%
import os

image_folder = "data2"
image_files = [f for f in os.listdir(image_folder) if f.lower().endswith('.jpg')]

for image_file in image_files:
    image_path = os.path.join(image_folder, image_file)
    with open(image_path, "rb") as f:
        image_base64 = base64.b64encode(f.read()).decode("utf-8")
    
    mime_type = "image/jpeg"
    
    response = client.chat.completions.create(
        model="gpt-4o-mini",
        messages=[
            {
                "role": "system",
                "content": "You extract all text and information from images, especially presentation slides as a text. Ignore footers"
            },
            {
                "role": "user",
                "content": [
                    {"type": "text", "text": f"Extract all text, titles, content, and any structured information from this slide image as a JSON object. Include slide number if visible: {image_file}"},
                    {"type": "image_url", "image_url": {"url": f"data:{mime_type};base64,{image_base64}"}}
                ]
            }
        ],
    )
    
    print(f"📊 Extracted Info from {image_file}:\n")
    print(response.choices[0].message.content)
    print("\n" + "="*50 + "\n")
# Out:
# 📊 Extracted Info from Slide4.JPG:
#
# ```json
# {
#   "slide_number": "4",
#   "title": "Service charges — Mobile Hall (hall-only)",
#   "content": {
#     "description": "Rates include: seating set-up (160–180), power/AV as offered, standard set-up + breakdown. Delivery is priced separately (next slide).",
#     "rates": [
#       {
#         "tier": "Conservative",
#         "hourly_rate": "$650/hr",
#         "daily_rate": "$5,000/day",
#         "notes": "Community events / weekday bookings"
#       },
#       {
#         "tier": "Middle",
#         "hourly_rate": "$800/hr",
#         "daily_rate": "$6,250/day",
#         "notes": "Most weekends + standard demand"
#       },
#       {
#         "tier": "High",
#         "hourly_rate": "$1,000/hr",
#         "daily_rate": "$7,750/day",
#         "notes": "Peak Saturdays / premium setups"
#       }
#     ],
#     "included_adjustments": [
#       "Extra hours (after day cap): same hourly tier rate, billed in 30-minute increments",
#       "Multi-day: 15–25% discount on days 2+ (because mobilization is already paid)",
#       "Peak-date premium: +10–20% for holiday weekends or last-minute bookings",
#       "Security / refundable deposit: typically 10–20% of booking total"
#     ]
#   }
# }
# ```
#
# ==================================================
#
# 📊 Extracted Info from Slide5.JPG:
#
# ```json
# {
#   "slide_number": "5",
#   "title": "Service charges — Restrooms (toilet-only)",
#   "content": {
#     "positioning": "guest-facing restrooms priced above standard porta potties (cleaner look, better experience).",
#     "pricing": [
#       {
#         "category": "Conservative",
#         "hourly_rate": "$65/hr",
#         "daily_rate_weekday": "$250/day",
#         "daily_rate_weekend": "$1,000/day",
#         "note": "Weekday or low-demand periods"
#       },
#       {
#         "category": "Middle",
#         "hourly_rate": "$80/hr",
#         "daily_rate_weekday": "$300/day",
#         "daily_rate_weekend": "$1,200/day",
#         "note": "Most events / standard weekends"
#       },
#       {
#         "category": "High",
#         "hourly_rate": "$100/hr",
#         "daily_rate_weekday": "$400/day",
#         "daily_rate_weekend": "$1,600/day",
#         "note": "Peak weekends / premium presentation"
#       }
#     ],
#     "typical_market_anchors": {
#       "location": "LA",
#       "details": [
#         "Standard event portable toilets in LA are often quoted around ~$146–$190 per day (varies by vendor, service, and delivery).",
#         "Other LA estimates put a portable toilet around ~$227–$324 for event use (depending on quantity/features), plus delivery.",
#         "Luxury / guest-facing options are commonly priced higher (often hundreds per unit/day)."
#       ]
#     },
#     "additional_notes": "Delivery / pickup is typically priced as a separate 'mobilization' fee (distance + time + fuel)."
#   }
# }
# ```
#
# ==================================================
#
# 📊 Extracted Info from Slide6.JPG:
#
# ```json
# {
#   "slide_number": 6,
#   "title": "Bundles — Hall + Restrooms (best-selling packages)",
#   "description": "Bundles are designed so your average booking lands near $7,500–$8,000 (aligns with your business-plan revenue scenarios).",
#   "packages": [
#     {
#       "name": "Essentials",
#       "description": "Hall day + 2 restroom units",
#       "price1": "$5,700",
#       "price2": "$7,000",
#       "price3": "$8,750"
#     },
#     {
#       "name": "Full Turnkey",
#       "description": "Hall day + 4 restroom units",
#       "price1": "$6,000",
#       "price2": "$7,450",
#       "price3": "$9,250"
#     },
#     {
#       "name": "Premium",
#       "description": "Full Turnkey + attendant + premium cleaning",
#       "price1": "$6,600",
#       "price2": "$8,200",
#       "price3": "$10,200"
#     }
#   ],
#   "recommended_rate_card": {
#     "launch": {
#       "notes": [
#         "Weekdays: price close to Conservative (fill the calendar)",
#         "Standard weekends: price at Middle (your baseline)",
#         "Peak Saturdays / short lead time: price at High (+10–20% if needed)",
#         "Note: add delivery/setup as a separate mobilization fee (see next slide)."
#       ]
#     }
#   }
# }
# ```
#
# ==================================================
#
# 📊 Extracted Info from Slide7.JPG:
#
# ```json
# {
#   "slide_number": "7",
#   "title": "Delivery, fees, and policies (how you protect margin)",
#   "content": {
#     "Mobilization (delivery + setup)": [
#       {
#         "item": "Base delivery/setup (0–25 mi)",
#         "price_range": "$650–$950"
#       },
#       {
#         "item": "25–60 mi",
#         "price_range": "$6–$10 per mile (or quote by route)"
#       },
#       {
#         "item": "Site complexity (stairs, long pushes, tight access)",
#         "price_range": "$150–$500"
#       },
#       {
#         "item": "Early AM / late-night load-out",
#         "price_range": "$150–$350"
#       }
#     ],
#     "Why charge this separately?": "It protects margin when fuel, traffic, route time, and staffing swing by location — without changing your advertised package rate.",
#     "Standard fees + rules": [
#       {
#         "item": "Refundable security deposit",
#         "details": "10–20% of booking"
#       },
#       {
#         "item": "Cleaning / sanitation",
#         "details": "included for normal use; deep-clean fee if needed ($150–$500)"
#       },
#       {
#         "item": "Damage waiver (optional)",
#         "details": "3–5% of booking"
#       },
#       {
#         "item": "Overtime",
#         "details": "billed at hourly tier (30-min increments)"
#       },
#       {
#         "item": "Cancellation",
#         "details": "keep deposit inside 7–14 days (scale by lead time)"
#       },
#       {
#         "item": "Payment terms",
#         "details": "50% to book, 50% due before delivery"
#       }
#     ],
#     "Optional upsells": [
#       "On-site attendant",
#       "Mid-event pump/refresh",
#       "Extra trash handling",
#       "Premium lighting / decor"
#     ]
#   }
# }
# ```
#
# ==================================================
