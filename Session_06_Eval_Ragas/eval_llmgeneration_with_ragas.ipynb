# %%
# %pip install pytest

# %%
reference_data = [
  {
    "question": "What is the company's policy on remote work?", 
    "ground_truth": "Remote work is allowed up to 3 days per week.", #Expected llm generated answer
    "context": "Remote work is allowed up to 3 days per week." #Expected retrieved context
  }
]
question = reference_data[0]['question']
ground_truth = reference_data[0]['ground_truth']
context = reference_data[0]['context']
print (f"question: {question}")
print (f"ground_truth: {ground_truth}")
print (f"context: {context}")
# Out:
# question: What is the company's policy on remote work?
# ground_truth: Remote work is allowed up to 3 days per week.
# context: Remote work is allowed up to 3 days per week.

# %%
# Retrieve context from Milvus DB

from milvus_chatbot_with_rag import retrieve_similiar_contexts, generate_answer

def perform_retrieval(question):

    retrieved_context = retrieve_similiar_contexts(question, "employee_policies", 1)[0]['content']
    print (f"perform_retrieval.retrieved_context: {retrieved_context}")
    return retrieved_context

# Generate answer using LLM

question = "What is the company's policy on remote work?"
context = perform_retrieval(question)
answer = generate_answer(question, context)
answer
# Out:
# perform_retrieval.retrieved_context: Remote work is allowed up to 3 days per week.
# 'Remote work is allowed up to 3 days per week.'

# %%
# %pip install ragas datasets
# Out:
# Collecting ragas
#   Downloading ragas-0.4.0-py3-none-any.whl.metadata (22 kB)
# Collecting datasets
#   Downloading datasets-4.4.1-py3-none-any.whl.metadata (19 kB)
# Requirement already satisfied: numpy<3.0.0,>=1.21.0 in c:\users\alban ssonko\training\10_2025_gen_ai_training\generative_ai_lab\.venv\lib\site-packages (from ragas) (2.3.4)
# Collecting tiktoken (from ragas)
#   Downloading tiktoken-0.12.0-cp313-cp313-win_amd64.whl.metadata (6.9 kB)
# Requirement already satisfied: pydantic>=2.0.0 in c:\users\alban ssonko\training\10_2025_gen_ai_training\generative_ai_lab\.venv\lib\site-packages (from ragas) (2.12.3)
# Requirement already satisfied: nest-asyncio in c:\users\alban ssonko\training\10_2025_gen_ai_training\generative_ai_lab\.venv\lib\site-packages (from ragas) (1.6.0)
# Collecting appdirs (from ragas)
#   Downloading appdirs-1.4.4-py2.py3-none-any.whl.metadata (9.0 kB)
# Collecting diskcache>=5.6.3 (from ragas)
#   Downloading diskcache-5.6.3-py3-none-any.whl.metadata (20 kB)
# Collecting typer (from ragas)
#   Downloading typer-0.20.0-py3-none-any.whl.metadata (16 kB)
# Collecting rich (from ragas)
#   Downloading rich-14.2.0-py3-none-any.whl.metadata (18 kB)
# Requirement already satisfied: openai>=1.0.0 in c:\users\alban ssonko\training\10_2025_gen_ai_training\generative_ai_lab\.venv\lib\site-packages (from ragas) (2.6.1)
# Requirement already satisfied: tqdm in c:\users\alban ssonko\training\10_2025_gen_ai_training\generative_ai_lab\.venv\lib\site-packages (from ragas) (4.67.1)
# Collecting instructor (from ragas)
#   Downloading instructor-1.13.0-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: pillow>=10.4.0 in c:\users\alban ssonko\training\10_2025_gen_ai_training\generative_ai_lab\.venv\lib\site-packages (from ragas) (12.0.0)
# Requirement already satisfied: networkx in c:\users\alban ssonko\training\10_2025_gen_ai_training\generative_ai_lab\.venv\lib\site-packages (from ragas) (3.5)
# Collecting scikit-network (from ragas)
#   Downloading scikit_network-0.33.5-cp313-cp313-win_amd64.whl.metadata (4.6 kB)
# Collecting langchain (from ragas)
#   Downloading langchain-1.1.2-py3-none-any.whl.metadata (4.9 kB)
# Collecting langchain-core (from ragas)
#   Downloading langchain_core-1.1.1-py3-none-any.whl.metadata (3.7 kB)
# Collecting langchain-community (from ragas)
#   Downloading langchain_community-0.4.1-py3-none-any.whl.metadata (3.0 kB)
# Collecting langchain_openai (from ragas)
#   Downloading langchain_openai-1.1.0-py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: filelock in c:\users\alban ssonko\training\10_2025_gen_ai_training\generative_ai_lab\.venv\lib\site-packages (from datasets) (3.20.0)
# Collecting pyarrow>=21.0.0 (from datasets)
#   Downloading pyarrow-22.0.0-cp313-cp313-win_amd64.whl.metadata (3.3 kB)
# Collecting dill<0.4.1,>=0.3.0 (from datasets)
#   Downloading dill-0.4.0-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: pandas in c:\users\alban ssonko\training\10_2025_gen_ai_training\generative_ai_lab\.venv\lib\site-packages (from datasets) (2.3.3)
# Requirement already satisfied: requests>=2.32.2 in c:\users\alban ssonko\training\10_2025_gen_ai_training\generative_ai_lab\.venv\lib\site-packages (from datasets) (2.32.5)
# Requirement already satisfied: httpx<1.0.0 in c:\users\alban ssonko\training\10_2025_gen_ai_training\generative_ai_lab\.venv\lib\site-packages (from datasets) (0.28.1)
# Collecting xxhash (from datasets)
#   Downloading xxhash-3.6.0-cp313-cp313-win_amd64.whl.metadata (13 kB)
# Collecting multiprocess<0.70.19 (from datasets)
#   Downloading multiprocess-0.70.18-py313-none-any.whl.metadata (7.2 kB)
# Requirement already satisfied: fsspec<=2025.10.0,>=2023.1.0 in c:\users\alban ssonko\training\10_2025_gen_ai_training\generative_ai_lab\.venv\lib\site-packages (from fsspec[http]<=2025.10.0,>=2023.1.0->datasets) (2025.10.0)
# Requirement already satisfied: huggingface-hub<2.0,>=0.25.0 in c:\users\alban ssonko\training\10_2025_gen_ai_training\generative_ai_lab\.venv\lib\site-packages (from datasets) (0.36.0)
# Requirement already satisfied: packaging in c:\users\alban ssonko\training\10_2025_gen_ai_training\generative_ai_lab\.venv\lib\site-packages (from datasets) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\alban ssonko\training\10_2025_gen_ai_training\generative_ai_lab\.venv\lib\site-packages (from datasets) (6.0.3)
# Collecting aiohttp!=4.0.0a0,!=4.0.0a1 (from fsspec[http]<=2025.10.0,>=2023.1.0->datasets)
#   Downloading aiohttp-3.13.2-cp313-cp313-win_amd64.whl.metadata (8.4 kB)
# Requirement already satisfied: anyio in c:\users\alban ssonko\training\10_2025_gen_ai_training\generative_ai_lab\.venv\lib\site-packages (from httpx<1.0.0->datasets) (4.11.0)
# Requirement already satisfied: certifi in c:\users\alban ssonko\training\10_2025_gen_ai_training\generative_ai_lab\.venv\lib\site-packages (from httpx<1.0.0->datasets) (2025.10.5)
# Requirement already satisfied: httpcore==1.* in c:\users\alban ssonko\training\10_2025_gen_ai_training\generative_ai_lab\.venv\lib\site-packages (from httpx<1.0.0->datasets) (1.0.9)
# Requirement already satisfied: idna in c:\users\alban ssonko\training\10_2025_gen_ai_training\generative_ai_lab\.venv\lib\site-packages (from httpx<1.0.0->datasets) (3.11)
# Requirement already satisfied: h11>=0.16 in c:\users\alban ssonko\training\10_2025_gen_ai_training\generative_ai_lab\.venv\lib\site-packages (from httpcore==1.*->httpx<1.0.0->datasets) (0.16.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\alban ssonko\training\10_2025_gen_ai_training\generative_ai_lab\.venv\lib\site-packages (from huggingface-hub<2.0,>=0.25.0->datasets) (4.15.0)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\users\alban ssonko\training\10_2025_gen_ai_training\generative_ai_lab\.venv\lib\site-packages (from openai>=1.0.0->ragas) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.10.0 in c:\users\alban ssonko\training\10_2025_gen_ai_training\generative_ai_lab\.venv\lib\site-packages (from openai>=1.0.0->ragas) (0.11.1)
# Requirement already satisfied: sniffio in c:\users\alban ssonko\training\10_2025_gen_ai_training\generative_ai_lab\.venv\lib\site-packages (from openai>=1.0.0->ragas) (1.3.1)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\alban ssonko\training\10_2025_gen_ai_training\generative_ai_lab\.venv\lib\site-packages (from pydantic>=2.0.0->ragas) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.4 in c:\users\alban ssonko\training\10_2025_gen_ai_training\generative_ai_lab\.venv\lib\site-packages (from pydantic>=2.0.0->ragas) (2.41.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\users\alban ssonko\training\10_2025_gen_ai_training\generative_ai_lab\.venv\lib\site-packages (from pydantic>=2.0.0->ragas) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\alban ssonko\training\10_2025_gen_ai_training\generative_ai_lab\.venv\lib\site-packages (from requests>=2.32.2->datasets) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\alban ssonko\training\10_2025_gen_ai_training\generative_ai_lab\.venv\lib\site-packages (from requests>=2.32.2->datasets) (2.5.0)
# Requirement already satisfied: colorama in c:\users\alban ssonko\training\10_2025_gen_ai_training\generative_ai_lab\.venv\lib\site-packages (from tqdm->ragas) (0.4.6)
# Collecting docstring-parser<1.0,>=0.16 (from instructor->ragas)
#   Downloading docstring_parser-0.17.0-py3-none-any.whl.metadata (3.5 kB)
# Requirement already satisfied: jinja2<4.0.0,>=3.1.4 in c:\users\alban ssonko\training\10_2025_gen_ai_training\generative_ai_lab\.venv\lib\site-packages (from instructor->ragas) (3.1.6)
# Collecting pre-commit>=4.3.0 (from instructor->ragas)
#   Downloading pre_commit-4.5.0-py2.py3-none-any.whl.metadata (1.2 kB)
# Collecting tenacity<10.0.0,>=8.2.3 (from instructor->ragas)
#   Downloading tenacity-9.1.2-py3-none-any.whl.metadata (1.2 kB)
# Collecting ty>=0.0.1a23 (from instructor->ragas)
#   Downloading ty-0.0.1a31-py3-none-win_amd64.whl.metadata (4.6 kB)
# Collecting markdown-it-py>=2.2.0 (from rich->ragas)
#   Downloading markdown_it_py-4.0.0-py3-none-any.whl.metadata (7.3 kB)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\alban ssonko\training\10_2025_gen_ai_training\generative_ai_lab\.venv\lib\site-packages (from rich->ragas) (2.19.2)
# Collecting click>=8.0.0 (from typer->ragas)
#   Downloading click-8.3.1-py3-none-any.whl.metadata (2.6 kB)
# Collecting shellingham>=1.3.0 (from typer->ragas)
#   Using cached shellingham-1.5.4-py2.py3-none-any.whl.metadata (3.5 kB)
# Collecting langgraph<1.1.0,>=1.0.2 (from langchain->ragas)
#   Downloading langgraph-1.0.4-py3-none-any.whl.metadata (7.8 kB)
# Collecting jsonpatch<2.0.0,>=1.33.0 (from langchain-core->ragas)
#   Downloading jsonpatch-1.33-py2.py3-none-any.whl.metadata (3.0 kB)
# Collecting langsmith<1.0.0,>=0.3.45 (from langchain-core->ragas)
#   Downloading langsmith-0.4.55-py3-none-any.whl.metadata (15 kB)
# Collecting uuid-utils<1.0,>=0.12.0 (from langchain-core->ragas)
#   Downloading uuid_utils-0.12.0-cp39-abi3-win_amd64.whl.metadata (1.1 kB)
# Collecting langchain-classic<2.0.0,>=1.0.0 (from langchain-community->ragas)
#   Downloading langchain_classic-1.0.0-py3-none-any.whl.metadata (3.9 kB)
# Collecting SQLAlchemy<3.0.0,>=1.4.0 (from langchain-community->ragas)
#   Downloading sqlalchemy-2.0.44-cp313-cp313-win_amd64.whl.metadata (9.8 kB)
# Collecting dataclasses-json<0.7.0,>=0.6.7 (from langchain-community->ragas)
#   Downloading dataclasses_json-0.6.7-py3-none-any.whl.metadata (25 kB)
# Collecting pydantic-settings<3.0.0,>=2.10.1 (from langchain-community->ragas)
#   Downloading pydantic_settings-2.12.0-py3-none-any.whl.metadata (3.4 kB)
# Collecting httpx-sse<1.0.0,>=0.4.0 (from langchain-community->ragas)
#   Downloading httpx_sse-0.4.3-py3-none-any.whl.metadata (9.7 kB)
# Requirement already satisfied: regex>=2022.1.18 in c:\users\alban ssonko\training\10_2025_gen_ai_training\generative_ai_lab\.venv\lib\site-packages (from tiktoken->ragas) (2025.11.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\alban ssonko\training\10_2025_gen_ai_training\generative_ai_lab\.venv\lib\site-packages (from pandas->datasets) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\alban ssonko\training\10_2025_gen_ai_training\generative_ai_lab\.venv\lib\site-packages (from pandas->datasets) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\alban ssonko\training\10_2025_gen_ai_training\generative_ai_lab\.venv\lib\site-packages (from pandas->datasets) (2025.2)
# Requirement already satisfied: scipy>=1.7.3 in c:\users\alban ssonko\training\10_2025_gen_ai_training\generative_ai_lab\.venv\lib\site-packages (from scikit-network->ragas) (1.16.3)
# Collecting aiohappyeyeballs>=2.5.0 (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.10.0,>=2023.1.0->datasets)
#   Downloading aiohappyeyeballs-2.6.1-py3-none-any.whl.metadata (5.9 kB)
# Collecting aiosignal>=1.4.0 (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.10.0,>=2023.1.0->datasets)
#   Downloading aiosignal-1.4.0-py3-none-any.whl.metadata (3.7 kB)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\alban ssonko\training\10_2025_gen_ai_training\generative_ai_lab\.venv\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.10.0,>=2023.1.0->datasets) (25.4.0)
# Collecting frozenlist>=1.1.1 (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.10.0,>=2023.1.0->datasets)
#   Downloading frozenlist-1.8.0-cp313-cp313-win_amd64.whl.metadata (21 kB)
# Collecting multidict<7.0,>=4.5 (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.10.0,>=2023.1.0->datasets)
#   Downloading multidict-6.7.0-cp313-cp313-win_amd64.whl.metadata (5.5 kB)
# Collecting propcache>=0.2.0 (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.10.0,>=2023.1.0->datasets)
#   Downloading propcache-0.4.1-cp313-cp313-win_amd64.whl.metadata (14 kB)
# Collecting yarl<2.0,>=1.17.0 (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.10.0,>=2023.1.0->datasets)
#   Downloading yarl-1.22.0-cp313-cp313-win_amd64.whl.metadata (77 kB)
# Collecting marshmallow<4.0.0,>=3.18.0 (from dataclasses-json<0.7.0,>=0.6.7->langchain-community->ragas)
#   Downloading marshmallow-3.26.1-py3-none-any.whl.metadata (7.3 kB)
# Collecting typing-inspect<1,>=0.4.0 (from dataclasses-json<0.7.0,>=0.6.7->langchain-community->ragas)
#   Downloading typing_inspect-0.9.0-py3-none-any.whl.metadata (1.5 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\alban ssonko\training\10_2025_gen_ai_training\generative_ai_lab\.venv\lib\site-packages (from jinja2<4.0.0,>=3.1.4->instructor->ragas) (3.0.3)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\alban ssonko\training\10_2025_gen_ai_training\generative_ai_lab\.venv\lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core->ragas) (3.0.0)
# Collecting langchain-text-splitters<2.0.0,>=1.0.0 (from langchain-classic<2.0.0,>=1.0.0->langchain-community->ragas)
#   Downloading langchain_text_splitters-1.0.0-py3-none-any.whl.metadata (2.6 kB)
# Collecting langgraph-checkpoint<4.0.0,>=2.1.0 (from langgraph<1.1.0,>=1.0.2->langchain->ragas)
#   Downloading langgraph_checkpoint-3.0.1-py3-none-any.whl.metadata (4.7 kB)
# Collecting langgraph-prebuilt<1.1.0,>=1.0.2 (from langgraph<1.1.0,>=1.0.2->langchain->ragas)
#   Downloading langgraph_prebuilt-1.0.5-py3-none-any.whl.metadata (5.2 kB)
# Collecting langgraph-sdk<0.3.0,>=0.2.2 (from langgraph<1.1.0,>=1.0.2->langchain->ragas)
#   Downloading langgraph_sdk-0.2.12-py3-none-any.whl.metadata (1.6 kB)
# Requirement already satisfied: orjson>=3.9.14 in c:\users\alban ssonko\training\10_2025_gen_ai_training\generative_ai_lab\.venv\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core->ragas) (3.11.4)
# Collecting requests-toolbelt>=1.0.0 (from langsmith<1.0.0,>=0.3.45->langchain-core->ragas)
#   Downloading requests_toolbelt-1.0.0-py2.py3-none-any.whl.metadata (14 kB)
# Collecting zstandard>=0.23.0 (from langsmith<1.0.0,>=0.3.45->langchain-core->ragas)
#   Downloading zstandard-0.25.0-cp313-cp313-win_amd64.whl.metadata (3.3 kB)
# Collecting mdurl~=0.1 (from markdown-it-py>=2.2.0->rich->ragas)
#   Downloading mdurl-0.1.2-py3-none-any.whl.metadata (1.6 kB)
# Collecting cfgv>=2.0.0 (from pre-commit>=4.3.0->instructor->ragas)
#   Downloading cfgv-3.5.0-py2.py3-none-any.whl.metadata (8.9 kB)
# Collecting identify>=1.0.0 (from pre-commit>=4.3.0->instructor->ragas)
#   Downloading identify-2.6.15-py2.py3-none-any.whl.metadata (4.4 kB)
# Collecting nodeenv>=0.11.1 (from pre-commit>=4.3.0->instructor->ragas)
#   Downloading nodeenv-1.9.1-py2.py3-none-any.whl.metadata (21 kB)
# Collecting virtualenv>=20.10.0 (from pre-commit>=4.3.0->instructor->ragas)
#   Downloading virtualenv-20.35.4-py3-none-any.whl.metadata (4.6 kB)
# Requirement already satisfied: python-dotenv>=0.21.0 in c:\users\alban ssonko\training\10_2025_gen_ai_training\generative_ai_lab\.venv\lib\site-packages (from pydantic-settings<3.0.0,>=2.10.1->langchain-community->ragas) (1.2.1)
# Requirement already satisfied: six>=1.5 in c:\users\alban ssonko\training\10_2025_gen_ai_training\generative_ai_lab\.venv\lib\site-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.17.0)
# Collecting greenlet>=1 (from SQLAlchemy<3.0.0,>=1.4.0->langchain-community->ragas)
#   Downloading greenlet-3.3.0-cp313-cp313-win_amd64.whl.metadata (4.2 kB)
# Collecting ormsgpack>=1.12.0 (from langgraph-checkpoint<4.0.0,>=2.1.0->langgraph<1.1.0,>=1.0.2->langchain->ragas)
#   Downloading ormsgpack-1.12.0-cp313-cp313-win_amd64.whl.metadata (1.2 kB)
# Collecting mypy-extensions>=0.3.0 (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7.0,>=0.6.7->langchain-community->ragas)
#   Downloading mypy_extensions-1.1.0-py3-none-any.whl.metadata (1.1 kB)
# Collecting distlib<1,>=0.3.7 (from virtualenv>=20.10.0->pre-commit>=4.3.0->instructor->ragas)
#   Downloading distlib-0.4.0-py2.py3-none-any.whl.metadata (5.2 kB)
# Requirement already satisfied: platformdirs<5,>=3.9.1 in c:\users\alban ssonko\training\10_2025_gen_ai_training\generative_ai_lab\.venv\lib\site-packages (from virtualenv>=20.10.0->pre-commit>=4.3.0->instructor->ragas) (4.5.0)
# Downloading ragas-0.4.0-py3-none-any.whl (397 kB)
# Downloading datasets-4.4.1-py3-none-any.whl (511 kB)
# Downloading dill-0.4.0-py3-none-any.whl (119 kB)
# Downloading diskcache-5.6.3-py3-none-any.whl (45 kB)
# Downloading multiprocess-0.70.18-py313-none-any.whl (151 kB)
# Downloading pyarrow-22.0.0-cp313-cp313-win_amd64.whl (28.0 MB)
#    ---------------------------------------- 0.0/28.0 MB ? eta -:--:--
#    --------- ------------------------------ 6.8/28.0 MB 32.0 MB/s eta 0:00:01
#    ------------------- -------------------- 13.9/28.0 MB 34.0 MB/s eta 0:00:01
#    ---------------------------- ----------- 19.7/28.0 MB 31.1 MB/s eta 0:00:01
#    ----------------------------------- ---- 24.9/28.0 MB 30.1 MB/s eta 0:00:01
#    ---------------------------------------  27.8/28.0 MB 28.8 MB/s eta 0:00:01
#    ---------------------------------------- 28.0/28.0 MB 25.3 MB/s eta 0:00:00
# Downloading appdirs-1.4.4-py2.py3-none-any.whl (9.6 kB)
# Downloading instructor-1.13.0-py3-none-any.whl (160 kB)
# Downloading rich-14.2.0-py3-none-any.whl (243 kB)
# Downloading typer-0.20.0-py3-none-any.whl (47 kB)
# Downloading langchain-1.1.2-py3-none-any.whl (102 kB)
# Downloading langchain_core-1.1.1-py3-none-any.whl (475 kB)
# Downloading langchain_community-0.4.1-py3-none-any.whl (2.5 MB)
#    ---------------------------------------- 0.0/2.5 MB ? eta -:--:--
#    ---------------------------------------- 2.5/2.5 MB 17.8 MB/s eta 0:00:00
# Downloading langchain_openai-1.1.0-py3-none-any.whl (84 kB)
# Downloading tiktoken-0.12.0-cp313-cp313-win_amd64.whl (879 kB)
#    ---------------------------------------- 0.0/879.1 kB ? eta -:--:--
#    --------------------------------------- 879.1/879.1 kB 14.6 MB/s eta 0:00:00
# Downloading scikit_network-0.33.5-cp313-cp313-win_amd64.whl (2.7 MB)
#    ---------------------------------------- 0.0/2.7 MB ? eta -:--:--
#    ---------------------------------------- 2.7/2.7 MB 19.3 MB/s eta 0:00:00
# Downloading xxhash-3.6.0-cp313-cp313-win_amd64.whl (31 kB)
# Downloading aiohttp-3.13.2-cp313-cp313-win_amd64.whl (452 kB)
# Downloading click-8.3.1-py3-none-any.whl (108 kB)
# Downloading dataclasses_json-0.6.7-py3-none-any.whl (28 kB)
# Downloading docstring_parser-0.17.0-py3-none-any.whl (36 kB)
# Downloading httpx_sse-0.4.3-py3-none-any.whl (9.0 kB)
# Downloading jsonpatch-1.33-py2.py3-none-any.whl (12 kB)
# Downloading langchain_classic-1.0.0-py3-none-any.whl (1.0 MB)
#    ---------------------------------------- 0.0/1.0 MB ? eta -:--:--
#    ---------------------------------------- 1.0/1.0 MB 16.6 MB/s eta 0:00:00
# Downloading langgraph-1.0.4-py3-none-any.whl (157 kB)
# Downloading langsmith-0.4.55-py3-none-any.whl (411 kB)
# Downloading markdown_it_py-4.0.0-py3-none-any.whl (87 kB)
# Downloading pre_commit-4.5.0-py2.py3-none-any.whl (226 kB)
# Downloading pydantic_settings-2.12.0-py3-none-any.whl (51 kB)
# Downloading shellingham-1.5.4-py2.py3-none-any.whl (9.8 kB)
# Downloading sqlalchemy-2.0.44-cp313-cp313-win_amd64.whl (2.1 MB)
#    ---------------------------------------- 0.0/2.1 MB ? eta -:--:--
#    ---------------------------------------- 2.1/2.1 MB 16.8 MB/s eta 0:00:00
# Downloading tenacity-9.1.2-py3-none-any.whl (28 kB)
# Downloading ty-0.0.1a31-py3-none-win_amd64.whl (9.9 MB)
#    ---------------------------------------- 0.0/9.9 MB ? eta -:--:--
#    ----------- ---------------------------- 2.9/9.9 MB 15.8 MB/s eta 0:00:01
#    ----------------------- ---------------- 5.8/9.9 MB 15.2 MB/s eta 0:00:01
#    ------------------------------------- -- 9.2/9.9 MB 15.0 MB/s eta 0:00:01
#    ---------------------------------------- 9.9/9.9 MB 13.9 MB/s eta 0:00:00
# Downloading uuid_utils-0.12.0-cp39-abi3-win_amd64.whl (183 kB)
# Downloading aiohappyeyeballs-2.6.1-py3-none-any.whl (15 kB)
# Downloading aiosignal-1.4.0-py3-none-any.whl (7.5 kB)
# Downloading cfgv-3.5.0-py2.py3-none-any.whl (7.4 kB)
# Downloading frozenlist-1.8.0-cp313-cp313-win_amd64.whl (43 kB)
# Downloading greenlet-3.3.0-cp313-cp313-win_amd64.whl (301 kB)
# Downloading identify-2.6.15-py2.py3-none-any.whl (99 kB)
# Downloading langchain_text_splitters-1.0.0-py3-none-any.whl (33 kB)
# Downloading langgraph_checkpoint-3.0.1-py3-none-any.whl (46 kB)
# Downloading langgraph_prebuilt-1.0.5-py3-none-any.whl (35 kB)
# Downloading langgraph_sdk-0.2.12-py3-none-any.whl (60 kB)
# Downloading marshmallow-3.26.1-py3-none-any.whl (50 kB)
# Downloading mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Downloading multidict-6.7.0-cp313-cp313-win_amd64.whl (45 kB)
# Downloading nodeenv-1.9.1-py2.py3-none-any.whl (22 kB)
# Downloading propcache-0.4.1-cp313-cp313-win_amd64.whl (40 kB)
# Downloading requests_toolbelt-1.0.0-py2.py3-none-any.whl (54 kB)
# Downloading typing_inspect-0.9.0-py3-none-any.whl (8.8 kB)
# Downloading virtualenv-20.35.4-py3-none-any.whl (6.0 MB)
#    ---------------------------------------- 0.0/6.0 MB ? eta -:--:--
#    ---------------------- ----------------- 3.4/6.0 MB 16.0 MB/s eta 0:00:01
#    ---------------------------------------- 6.0/6.0 MB 15.3 MB/s eta 0:00:00
# Downloading yarl-1.22.0-cp313-cp313-win_amd64.whl (86 kB)
# Downloading zstandard-0.25.0-cp313-cp313-win_amd64.whl (506 kB)
# Downloading distlib-0.4.0-py2.py3-none-any.whl (469 kB)
# Downloading mypy_extensions-1.1.0-py3-none-any.whl (5.0 kB)
# Downloading ormsgpack-1.12.0-cp313-cp313-win_amd64.whl (112 kB)
# Installing collected packages: distlib, appdirs, zstandard, xxhash, virtualenv, uuid-utils, ty, tenacity, shellingham, pyarrow, propcache, ormsgpack, nodeenv, mypy-extensions, multidict, mdurl, marshmallow, jsonpatch, identify, httpx-sse, greenlet, frozenlist, docstring-parser, diskcache, dill, click, cfgv, aiohappyeyeballs, yarl, typing-inspect, tiktoken, SQLAlchemy, scikit-network, requests-toolbelt, pre-commit, multiprocess, markdown-it-py, aiosignal, rich, pydantic-settings, langsmith, langgraph-sdk, dataclasses-json, aiohttp, typer, langchain-core, langgraph-checkpoint, langchain-text-splitters, langchain_openai, instructor, datasets, langgraph-prebuilt, langchain-classic, langgraph, langchain-community, langchain, ragas
# Successfully installed SQLAlchemy-2.0.44 aiohappyeyeballs-2.6.1 aiohttp-3.13.2 aiosignal-1.4.0 appdirs-1.4.4 cfgv-3.5.0 click-8.3.1 dataclasses-json-0.6.7 datasets-4.4.1 dill-0.4.0 diskcache-5.6.3 distlib-0.4.0 docstring-parser-0.17.0 frozenlist-1.8.0 greenlet-3.3.0 httpx-sse-0.4.3 identify-2.6.15 instructor-1.13.0 jsonpatch-1.33 langchain-1.1.2 langchain-classic-1.0.0 langchain-community-0.4.1 langchain-core-1.1.1 langchain-text-splitters-1.0.0 langchain_openai-1.1.0 langgraph-1.0.4 langgraph-checkpoint-3.0.1 langgraph-prebuilt-1.0.5 langgraph-sdk-0.2.12 langsmith-0.4.55 markdown-it-py-4.0.0 marshmallow-3.26.1 mdurl-0.1.2 multidict-6.7.0 multiprocess-0.70.18 mypy-extensions-1.1.0 nodeenv-1.9.1 ormsgpack-1.12.0 pre-commit-4.5.0 propcache-0.4.1 pyarrow-22.0.0 pydantic-settings-2.12.0 ragas-0.4.0 requests-toolbelt-1.0.0 rich-14.2.0 scikit-network-0.33.5 shellingham-1.5.4 tenacity-9.1.2 tiktoken-0.12.0 ty-0.0.1a31 typer-0.20.0 typing-inspect-0.9.0 uuid-utils-0.12.0 virtualenv-20.35.4 xxhash-3.6.0 yarl-1.22.0 zstandard-0.25.0
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.3.1 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from datasets import Dataset
from ragas import evaluate
from ragas.metrics import faithfulness, answer_correctness

from dotenv import load_dotenv
from openai import OpenAI
import os

# --- Load API Key ---
load_dotenv(override=True, dotenv_path="../.env")
my_api_key = os.getenv("OPENAI_API_KEY")


client = OpenAI(api_key=my_api_key)

# Question User asked
question = reference_data[0]['question']

# Reference context (should be a string)
reference_context = reference_data[0]['context']

# ground truth answer
ground_truth = reference_data[0]['ground_truth']

# Retrieved context (a string from perform_retrieval)
retrieved_context = [perform_retrieval(question)]
llm_answer = generate_answer(question, retrieved_context[0])

# Build dataset properly
dataset_dict = {
    "question": [question],
    "contexts": [retrieved_context],    # list of strings INSIDE another list
    "ground_truth": [ground_truth],   # single string/ reference answer
    "answer": [llm_answer]
}

print(f"dataset_dict: {dataset_dict}")

ragas_dataset = Dataset.from_dict(dataset_dict)
# Out:
# perform_retrieval.retrieved_context: Remote work is allowed up to 3 days per week.
# dataset_dict: {'question': ["What is the company's policy on remote work?"], 'contexts': [['Remote work is allowed up to 3 days per week.']], 'ground_truth': ['Remote work is allowed up to 3 days per week.'], 'answer': ['Remote work is allowed up to 3 days per week.']}

# %%
from ragas.llms.base import llm_factory
from ragas import evaluate
from ragas.metrics import answer_correctness

results = evaluate(
    dataset=ragas_dataset,
    metrics=[faithfulness, answer_correctness]  
)


print("LLM Generation Evaluation Results:")
results.to_pandas()
# Out:
# Evaluating:   0%|          | 0/2 [00:00<?, ?it/s]
# Exception raised in Job[1]: TypeError(Cannot use aembed_text() with a synchronous client. Use embed_text() instead.)
# LLM Generation Evaluation Results:
#                                      user_input  \
# 0  What is the company's policy on remote work?
#
#                                 retrieved_contexts  \
# 0  [Remote work is allowed up to 3 days per week.]
#
#                                         response  \
# 0  Remote work is allowed up to 3 days per week.
#
#                                        reference  faithfulness  \
# 0  Remote work is allowed up to 3 days per week.           1.0
#
#    answer_correctness
# 0                 NaN

# %%
from ragas.llms.base import llm_factory
from ragas import evaluate
from ragas.metrics import answer_correctness

# Create the modern LLM wrapper
client = OpenAI()
llm = llm_factory("gpt-4o-mini", client=client)

# Run evaluation
results = evaluate(
    dataset=ragas_dataset,
    metrics=[answer_correctness],
    llm=llm
)

print("LLM Generation Evaluation Results:")
results.to_pandas()
# Out:
# Evaluating:   0%|          | 0/1 [00:00<?, ?it/s]
# Exception raised in Job[0]: TypeError(Cannot use aembed_text() with a synchronous client. Use embed_text() instead.)
# LLM Generation Evaluation Results:
#                                      user_input  \
# 0  What is the company's policy on remote work?
#
#                                 retrieved_contexts  \
# 0  [Remote work is allowed up to 3 days per week.]
#
#                                         response  \
# 0  Remote work is allowed up to 3 days per week.
#
#                                        reference  answer_correctness
# 0  Remote work is allowed up to 3 days per week.                 NaN
