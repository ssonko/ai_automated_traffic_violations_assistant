# %%
reference_data = [
  {
    "question": "What is the company's policy on remote work?", 
    "ground_truth": "Remote work is allowed up to 3 days per week. ", #Expected llm generated answer
    "context": "Remote work is allowed up to 3 days per week." #Expected retrieved context
  }
]
question = reference_data[0]['question']
ground_truth = reference_data[0]['ground_truth']
context = reference_data[0]['context']
print (f"question: {question}")
print (f"ground_truth: {ground_truth}")
print (f"context: {context}")
# Out:
# question: What is the company's policy on remote work?
# ground_truth: Remote work is allowed up to 3 days per week.
# context: Remote work is allowed up to 3 days per week.

# %%
# Retrieve context from Milvus DB

from milvus_chatbot_with_rag import retrieve_similiar_contexts

def perform_retrieval(question):

    retrieved_context = retrieve_similiar_contexts(question, "employee_policies", 1)[0]['content']
    print (f"perform_retrieval.retrieved_context: {retrieved_context}")
    return retrieved_context

# Validate retrieved context against reference data    
perform_retrieval("What is the company's policy on remote work?")
# Out:
# perform_retrieval.retrieved_context: Remote work is allowed up to 3 days per week.
# 'Remote work is allowed up to 3 days per week.'

# %%
# %pip install ragas datasets
# Out:
# Requirement already satisfied: ragas in c:\users\alban ssonko\training\10_2025_gen_ai_training\generative_ai_lab\.venv\lib\site-packages (0.4.0)
# Requirement already satisfied: datasets in c:\users\alban ssonko\training\10_2025_gen_ai_training\generative_ai_lab\.venv\lib\site-packages (4.4.1)
# Requirement already satisfied: numpy<3.0.0,>=1.21.0 in c:\users\alban ssonko\training\10_2025_gen_ai_training\generative_ai_lab\.venv\lib\site-packages (from ragas) (2.3.4)
# Requirement already satisfied: tiktoken in c:\users\alban ssonko\training\10_2025_gen_ai_training\generative_ai_lab\.venv\lib\site-packages (from ragas) (0.12.0)
# Requirement already satisfied: pydantic>=2.0.0 in c:\users\alban ssonko\training\10_2025_gen_ai_training\generative_ai_lab\.venv\lib\site-packages (from ragas) (2.12.3)
# Requirement already satisfied: nest-asyncio in c:\users\alban ssonko\training\10_2025_gen_ai_training\generative_ai_lab\.venv\lib\site-packages (from ragas) (1.6.0)
# Requirement already satisfied: appdirs in c:\users\alban ssonko\training\10_2025_gen_ai_training\generative_ai_lab\.venv\lib\site-packages (from ragas) (1.4.4)
# Requirement already satisfied: diskcache>=5.6.3 in c:\users\alban ssonko\training\10_2025_gen_ai_training\generative_ai_lab\.venv\lib\site-packages (from ragas) (5.6.3)
# Requirement already satisfied: typer in c:\users\alban ssonko\training\10_2025_gen_ai_training\generative_ai_lab\.venv\lib\site-packages (from ragas) (0.20.0)
# Requirement already satisfied: rich in c:\users\alban ssonko\training\10_2025_gen_ai_training\generative_ai_lab\.venv\lib\site-packages (from ragas) (14.2.0)
# Requirement already satisfied: openai>=1.0.0 in c:\users\alban ssonko\training\10_2025_gen_ai_training\generative_ai_lab\.venv\lib\site-packages (from ragas) (2.6.1)
# Requirement already satisfied: tqdm in c:\users\alban ssonko\training\10_2025_gen_ai_training\generative_ai_lab\.venv\lib\site-packages (from ragas) (4.67.1)
# Requirement already satisfied: instructor in c:\users\alban ssonko\training\10_2025_gen_ai_training\generative_ai_lab\.venv\lib\site-packages (from ragas) (1.13.0)
# Requirement already satisfied: pillow>=10.4.0 in c:\users\alban ssonko\training\10_2025_gen_ai_training\generative_ai_lab\.venv\lib\site-packages (from ragas) (12.0.0)
# Requirement already satisfied: networkx in c:\users\alban ssonko\training\10_2025_gen_ai_training\generative_ai_lab\.venv\lib\site-packages (from ragas) (3.5)
# Requirement already satisfied: scikit-network in c:\users\alban ssonko\training\10_2025_gen_ai_training\generative_ai_lab\.venv\lib\site-packages (from ragas) (0.33.5)
# Requirement already satisfied: langchain in c:\users\alban ssonko\training\10_2025_gen_ai_training\generative_ai_lab\.venv\lib\site-packages (from ragas) (1.1.2)
# Requirement already satisfied: langchain-core in c:\users\alban ssonko\training\10_2025_gen_ai_training\generative_ai_lab\.venv\lib\site-packages (from ragas) (1.1.1)
# Requirement already satisfied: langchain-community in c:\users\alban ssonko\training\10_2025_gen_ai_training\generative_ai_lab\.venv\lib\site-packages (from ragas) (0.4.1)
# Requirement already satisfied: langchain_openai in c:\users\alban ssonko\training\10_2025_gen_ai_training\generative_ai_lab\.venv\lib\site-packages (from ragas) (1.1.0)
# Requirement already satisfied: filelock in c:\users\alban ssonko\training\10_2025_gen_ai_training\generative_ai_lab\.venv\lib\site-packages (from datasets) (3.20.0)
# Requirement already satisfied: pyarrow>=21.0.0 in c:\users\alban ssonko\training\10_2025_gen_ai_training\generative_ai_lab\.venv\lib\site-packages (from datasets) (22.0.0)
# Requirement already satisfied: dill<0.4.1,>=0.3.0 in c:\users\alban ssonko\training\10_2025_gen_ai_training\generative_ai_lab\.venv\lib\site-packages (from datasets) (0.4.0)
# Requirement already satisfied: pandas in c:\users\alban ssonko\training\10_2025_gen_ai_training\generative_ai_lab\.venv\lib\site-packages (from datasets) (2.3.3)
# Requirement already satisfied: requests>=2.32.2 in c:\users\alban ssonko\training\10_2025_gen_ai_training\generative_ai_lab\.venv\lib\site-packages (from datasets) (2.32.5)
# Requirement already satisfied: httpx<1.0.0 in c:\users\alban ssonko\training\10_2025_gen_ai_training\generative_ai_lab\.venv\lib\site-packages (from datasets) (0.28.1)
# Requirement already satisfied: xxhash in c:\users\alban ssonko\training\10_2025_gen_ai_training\generative_ai_lab\.venv\lib\site-packages (from datasets) (3.6.0)
# Requirement already satisfied: multiprocess<0.70.19 in c:\users\alban ssonko\training\10_2025_gen_ai_training\generative_ai_lab\.venv\lib\site-packages (from datasets) (0.70.18)
# Requirement already satisfied: fsspec<=2025.10.0,>=2023.1.0 in c:\users\alban ssonko\training\10_2025_gen_ai_training\generative_ai_lab\.venv\lib\site-packages (from fsspec[http]<=2025.10.0,>=2023.1.0->datasets) (2025.10.0)
# Requirement already satisfied: huggingface-hub<2.0,>=0.25.0 in c:\users\alban ssonko\training\10_2025_gen_ai_training\generative_ai_lab\.venv\lib\site-packages (from datasets) (0.36.0)
# Requirement already satisfied: packaging in c:\users\alban ssonko\training\10_2025_gen_ai_training\generative_ai_lab\.venv\lib\site-packages (from datasets) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\alban ssonko\training\10_2025_gen_ai_training\generative_ai_lab\.venv\lib\site-packages (from datasets) (6.0.3)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in c:\users\alban ssonko\training\10_2025_gen_ai_training\generative_ai_lab\.venv\lib\site-packages (from fsspec[http]<=2025.10.0,>=2023.1.0->datasets) (3.13.2)
# Requirement already satisfied: anyio in c:\users\alban ssonko\training\10_2025_gen_ai_training\generative_ai_lab\.venv\lib\site-packages (from httpx<1.0.0->datasets) (4.11.0)
# Requirement already satisfied: certifi in c:\users\alban ssonko\training\10_2025_gen_ai_training\generative_ai_lab\.venv\lib\site-packages (from httpx<1.0.0->datasets) (2025.10.5)
# Requirement already satisfied: httpcore==1.* in c:\users\alban ssonko\training\10_2025_gen_ai_training\generative_ai_lab\.venv\lib\site-packages (from httpx<1.0.0->datasets) (1.0.9)
# Requirement already satisfied: idna in c:\users\alban ssonko\training\10_2025_gen_ai_training\generative_ai_lab\.venv\lib\site-packages (from httpx<1.0.0->datasets) (3.11)
# Requirement already satisfied: h11>=0.16 in c:\users\alban ssonko\training\10_2025_gen_ai_training\generative_ai_lab\.venv\lib\site-packages (from httpcore==1.*->httpx<1.0.0->datasets) (0.16.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\alban ssonko\training\10_2025_gen_ai_training\generative_ai_lab\.venv\lib\site-packages (from huggingface-hub<2.0,>=0.25.0->datasets) (4.15.0)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\users\alban ssonko\training\10_2025_gen_ai_training\generative_ai_lab\.venv\lib\site-packages (from openai>=1.0.0->ragas) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.10.0 in c:\users\alban ssonko\training\10_2025_gen_ai_training\generative_ai_lab\.venv\lib\site-packages (from openai>=1.0.0->ragas) (0.11.1)
# Requirement already satisfied: sniffio in c:\users\alban ssonko\training\10_2025_gen_ai_training\generative_ai_lab\.venv\lib\site-packages (from openai>=1.0.0->ragas) (1.3.1)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\alban ssonko\training\10_2025_gen_ai_training\generative_ai_lab\.venv\lib\site-packages (from pydantic>=2.0.0->ragas) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.4 in c:\users\alban ssonko\training\10_2025_gen_ai_training\generative_ai_lab\.venv\lib\site-packages (from pydantic>=2.0.0->ragas) (2.41.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\users\alban ssonko\training\10_2025_gen_ai_training\generative_ai_lab\.venv\lib\site-packages (from pydantic>=2.0.0->ragas) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\alban ssonko\training\10_2025_gen_ai_training\generative_ai_lab\.venv\lib\site-packages (from requests>=2.32.2->datasets) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\alban ssonko\training\10_2025_gen_ai_training\generative_ai_lab\.venv\lib\site-packages (from requests>=2.32.2->datasets) (2.5.0)
# Requirement already satisfied: colorama in c:\users\alban ssonko\training\10_2025_gen_ai_training\generative_ai_lab\.venv\lib\site-packages (from tqdm->ragas) (0.4.6)
# Requirement already satisfied: docstring-parser<1.0,>=0.16 in c:\users\alban ssonko\training\10_2025_gen_ai_training\generative_ai_lab\.venv\lib\site-packages (from instructor->ragas) (0.17.0)
# Requirement already satisfied: jinja2<4.0.0,>=3.1.4 in c:\users\alban ssonko\training\10_2025_gen_ai_training\generative_ai_lab\.venv\lib\site-packages (from instructor->ragas) (3.1.6)
# Requirement already satisfied: pre-commit>=4.3.0 in c:\users\alban ssonko\training\10_2025_gen_ai_training\generative_ai_lab\.venv\lib\site-packages (from instructor->ragas) (4.5.0)
# Requirement already satisfied: tenacity<10.0.0,>=8.2.3 in c:\users\alban ssonko\training\10_2025_gen_ai_training\generative_ai_lab\.venv\lib\site-packages (from instructor->ragas) (9.1.2)
# Requirement already satisfied: ty>=0.0.1a23 in c:\users\alban ssonko\training\10_2025_gen_ai_training\generative_ai_lab\.venv\lib\site-packages (from instructor->ragas) (0.0.1a31)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\alban ssonko\training\10_2025_gen_ai_training\generative_ai_lab\.venv\lib\site-packages (from rich->ragas) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\alban ssonko\training\10_2025_gen_ai_training\generative_ai_lab\.venv\lib\site-packages (from rich->ragas) (2.19.2)
# Requirement already satisfied: click>=8.0.0 in c:\users\alban ssonko\training\10_2025_gen_ai_training\generative_ai_lab\.venv\lib\site-packages (from typer->ragas) (8.3.1)
# Requirement already satisfied: shellingham>=1.3.0 in c:\users\alban ssonko\training\10_2025_gen_ai_training\generative_ai_lab\.venv\lib\site-packages (from typer->ragas) (1.5.4)
# Requirement already satisfied: langgraph<1.1.0,>=1.0.2 in c:\users\alban ssonko\training\10_2025_gen_ai_training\generative_ai_lab\.venv\lib\site-packages (from langchain->ragas) (1.0.4)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in c:\users\alban ssonko\training\10_2025_gen_ai_training\generative_ai_lab\.venv\lib\site-packages (from langchain-core->ragas) (1.33)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in c:\users\alban ssonko\training\10_2025_gen_ai_training\generative_ai_lab\.venv\lib\site-packages (from langchain-core->ragas) (0.4.55)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in c:\users\alban ssonko\training\10_2025_gen_ai_training\generative_ai_lab\.venv\lib\site-packages (from langchain-core->ragas) (0.12.0)
# Requirement already satisfied: langchain-classic<2.0.0,>=1.0.0 in c:\users\alban ssonko\training\10_2025_gen_ai_training\generative_ai_lab\.venv\lib\site-packages (from langchain-community->ragas) (1.0.0)
# Requirement already satisfied: SQLAlchemy<3.0.0,>=1.4.0 in c:\users\alban ssonko\training\10_2025_gen_ai_training\generative_ai_lab\.venv\lib\site-packages (from langchain-community->ragas) (2.0.44)
# Requirement already satisfied: dataclasses-json<0.7.0,>=0.6.7 in c:\users\alban ssonko\training\10_2025_gen_ai_training\generative_ai_lab\.venv\lib\site-packages (from langchain-community->ragas) (0.6.7)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.10.1 in c:\users\alban ssonko\training\10_2025_gen_ai_training\generative_ai_lab\.venv\lib\site-packages (from langchain-community->ragas) (2.12.0)
# Requirement already satisfied: httpx-sse<1.0.0,>=0.4.0 in c:\users\alban ssonko\training\10_2025_gen_ai_training\generative_ai_lab\.venv\lib\site-packages (from langchain-community->ragas) (0.4.3)
# Requirement already satisfied: regex>=2022.1.18 in c:\users\alban ssonko\training\10_2025_gen_ai_training\generative_ai_lab\.venv\lib\site-packages (from tiktoken->ragas) (2025.11.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\alban ssonko\training\10_2025_gen_ai_training\generative_ai_lab\.venv\lib\site-packages (from pandas->datasets) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\alban ssonko\training\10_2025_gen_ai_training\generative_ai_lab\.venv\lib\site-packages (from pandas->datasets) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\alban ssonko\training\10_2025_gen_ai_training\generative_ai_lab\.venv\lib\site-packages (from pandas->datasets) (2025.2)
# Requirement already satisfied: scipy>=1.7.3 in c:\users\alban ssonko\training\10_2025_gen_ai_training\generative_ai_lab\.venv\lib\site-packages (from scikit-network->ragas) (1.16.3)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in c:\users\alban ssonko\training\10_2025_gen_ai_training\generative_ai_lab\.venv\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.10.0,>=2023.1.0->datasets) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in c:\users\alban ssonko\training\10_2025_gen_ai_training\generative_ai_lab\.venv\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.10.0,>=2023.1.0->datasets) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\alban ssonko\training\10_2025_gen_ai_training\generative_ai_lab\.venv\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.10.0,>=2023.1.0->datasets) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\alban ssonko\training\10_2025_gen_ai_training\generative_ai_lab\.venv\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.10.0,>=2023.1.0->datasets) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\alban ssonko\training\10_2025_gen_ai_training\generative_ai_lab\.venv\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.10.0,>=2023.1.0->datasets) (6.7.0)
# Requirement already satisfied: propcache>=0.2.0 in c:\users\alban ssonko\training\10_2025_gen_ai_training\generative_ai_lab\.venv\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.10.0,>=2023.1.0->datasets) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in c:\users\alban ssonko\training\10_2025_gen_ai_training\generative_ai_lab\.venv\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.10.0,>=2023.1.0->datasets) (1.22.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in c:\users\alban ssonko\training\10_2025_gen_ai_training\generative_ai_lab\.venv\lib\site-packages (from dataclasses-json<0.7.0,>=0.6.7->langchain-community->ragas) (3.26.1)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in c:\users\alban ssonko\training\10_2025_gen_ai_training\generative_ai_lab\.venv\lib\site-packages (from dataclasses-json<0.7.0,>=0.6.7->langchain-community->ragas) (0.9.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\alban ssonko\training\10_2025_gen_ai_training\generative_ai_lab\.venv\lib\site-packages (from jinja2<4.0.0,>=3.1.4->instructor->ragas) (3.0.3)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\alban ssonko\training\10_2025_gen_ai_training\generative_ai_lab\.venv\lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core->ragas) (3.0.0)
# Requirement already satisfied: langchain-text-splitters<2.0.0,>=1.0.0 in c:\users\alban ssonko\training\10_2025_gen_ai_training\generative_ai_lab\.venv\lib\site-packages (from langchain-classic<2.0.0,>=1.0.0->langchain-community->ragas) (1.0.0)
# Requirement already satisfied: langgraph-checkpoint<4.0.0,>=2.1.0 in c:\users\alban ssonko\training\10_2025_gen_ai_training\generative_ai_lab\.venv\lib\site-packages (from langgraph<1.1.0,>=1.0.2->langchain->ragas) (3.0.1)
# Requirement already satisfied: langgraph-prebuilt<1.1.0,>=1.0.2 in c:\users\alban ssonko\training\10_2025_gen_ai_training\generative_ai_lab\.venv\lib\site-packages (from langgraph<1.1.0,>=1.0.2->langchain->ragas) (1.0.5)
# Requirement already satisfied: langgraph-sdk<0.3.0,>=0.2.2 in c:\users\alban ssonko\training\10_2025_gen_ai_training\generative_ai_lab\.venv\lib\site-packages (from langgraph<1.1.0,>=1.0.2->langchain->ragas) (0.2.12)
# Requirement already satisfied: orjson>=3.9.14 in c:\users\alban ssonko\training\10_2025_gen_ai_training\generative_ai_lab\.venv\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core->ragas) (3.11.4)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in c:\users\alban ssonko\training\10_2025_gen_ai_training\generative_ai_lab\.venv\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core->ragas) (1.0.0)
# Requirement already satisfied: zstandard>=0.23.0 in c:\users\alban ssonko\training\10_2025_gen_ai_training\generative_ai_lab\.venv\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core->ragas) (0.25.0)
# Requirement already satisfied: mdurl~=0.1 in c:\users\alban ssonko\training\10_2025_gen_ai_training\generative_ai_lab\.venv\lib\site-packages (from markdown-it-py>=2.2.0->rich->ragas) (0.1.2)
# Requirement already satisfied: cfgv>=2.0.0 in c:\users\alban ssonko\training\10_2025_gen_ai_training\generative_ai_lab\.venv\lib\site-packages (from pre-commit>=4.3.0->instructor->ragas) (3.5.0)
# Requirement already satisfied: identify>=1.0.0 in c:\users\alban ssonko\training\10_2025_gen_ai_training\generative_ai_lab\.venv\lib\site-packages (from pre-commit>=4.3.0->instructor->ragas) (2.6.15)
# Requirement already satisfied: nodeenv>=0.11.1 in c:\users\alban ssonko\training\10_2025_gen_ai_training\generative_ai_lab\.venv\lib\site-packages (from pre-commit>=4.3.0->instructor->ragas) (1.9.1)
# Requirement already satisfied: virtualenv>=20.10.0 in c:\users\alban ssonko\training\10_2025_gen_ai_training\generative_ai_lab\.venv\lib\site-packages (from pre-commit>=4.3.0->instructor->ragas) (20.35.4)
# Requirement already satisfied: python-dotenv>=0.21.0 in c:\users\alban ssonko\training\10_2025_gen_ai_training\generative_ai_lab\.venv\lib\site-packages (from pydantic-settings<3.0.0,>=2.10.1->langchain-community->ragas) (1.2.1)
# Requirement already satisfied: six>=1.5 in c:\users\alban ssonko\training\10_2025_gen_ai_training\generative_ai_lab\.venv\lib\site-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.17.0)
# Requirement already satisfied: greenlet>=1 in c:\users\alban ssonko\training\10_2025_gen_ai_training\generative_ai_lab\.venv\lib\site-packages (from SQLAlchemy<3.0.0,>=1.4.0->langchain-community->ragas) (3.3.0)
# Requirement already satisfied: ormsgpack>=1.12.0 in c:\users\alban ssonko\training\10_2025_gen_ai_training\generative_ai_lab\.venv\lib\site-packages (from langgraph-checkpoint<4.0.0,>=2.1.0->langgraph<1.1.0,>=1.0.2->langchain->ragas) (1.12.0)
# Requirement already satisfied: mypy-extensions>=0.3.0 in c:\users\alban ssonko\training\10_2025_gen_ai_training\generative_ai_lab\.venv\lib\site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7.0,>=0.6.7->langchain-community->ragas) (1.1.0)
# Requirement already satisfied: distlib<1,>=0.3.7 in c:\users\alban ssonko\training\10_2025_gen_ai_training\generative_ai_lab\.venv\lib\site-packages (from virtualenv>=20.10.0->pre-commit>=4.3.0->instructor->ragas) (0.4.0)
# Requirement already satisfied: platformdirs<5,>=3.9.1 in c:\users\alban ssonko\training\10_2025_gen_ai_training\generative_ai_lab\.venv\lib\site-packages (from virtualenv>=20.10.0->pre-commit>=4.3.0->instructor->ragas) (4.5.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.3.1 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from datasets import Dataset
from ragas import evaluate
from ragas.metrics import context_precision, context_recall

from dotenv import load_dotenv
from openai import OpenAI
import os

# --- Load API Key ---
load_dotenv(override=True, dotenv_path="../.env")
my_api_key = os.getenv("OPENAI_API_KEY")


client = OpenAI(api_key=my_api_key)

# question = reference_data[0]['question']
# ground_truth = reference_data[0]['ground_truth']
# context = reference_data[0]['context']
# Question User asked
question = reference_data[0]['question']

# Reference context (should be a string)
reference_context = reference_data[0]['context']

# Retrieved context (a string from perform_retrieval)
retrieved_context = [perform_retrieval(question)]

# Build dataset properly
dataset_dict = {
    "question": [question],
    "contexts": [retrieved_context],      # list of strings INSIDE another list
    "ground_truth": [reference_context],   # single string
    "answer": [""]
}

print(f"dataset_dict: {dataset_dict}")

ragas_dataset = Dataset.from_dict(dataset_dict)

# Evaluate retrieval
results = evaluate(
    dataset=ragas_dataset,
    metrics=[context_precision, context_recall]
)
# Out:
# perform_retrieval.retrieved_context: Remote work is allowed up to 3 days per week.
# dataset_dict: {'question': ["What is the company's policy on remote work?"], 'contexts': [['Remote work is allowed up to 3 days per week.']], 'ground_truth': ['Remote work is allowed up to 3 days per week.'], 'answer': ['']}
# Evaluating:   0%|          | 0/2 [00:00<?, ?it/s]

# %%
print("Retrieval Evaluation Results:")
results.to_pandas()
# Out:
# Retrieval Evaluation Results:
#                                      user_input  \
# 0  What is the company's policy on remote work?
#
#                                 retrieved_contexts response  \
# 0  [Remote work is allowed up to 3 days per week.]
#
#                                        reference  context_precision  \
# 0  Remote work is allowed up to 3 days per week.                1.0
#
#    context_recall
# 0             1.0
