# %%
# %pip install openai python-dotenv

from dotenv import load_dotenv
import os

load_dotenv(override=True, dotenv_path=".env")  
my_api_key = os.getenv("OPENAI_API_KEY")

print(my_api_key[:5] + "..." + my_api_key[-5:])
# Out:
# sk-pr...gRpsA

# %%
from openai import OpenAI

client = OpenAI(api_key=my_api_key)

def ask_question(prompt):
    response = client.chat.completions.create(
        model="gpt-5-nano",
        messages=[
            {"role": "system", "content": "You are a creative Real-estate Listing Chatbot."},
            {"role": "user", "content": prompt}
        ]
    )
    return response.choices[0].message.content

# %%
user_prompt = input("Ask something: ")
response = ask_question(user_prompt)
print("\nOpenAI says:", response)
# Out:
# OpenAI says: There isn’t a single fixed speed. My response time depends on the prompt and system conditions. Roughly:
#
# - Short, simple prompts: usually 0.5–2 seconds of processing; total round-trip (including network) around 1–3 seconds.
# - Longer or more complex prompts: typically several seconds, sometimes 10+ seconds if a lot of reasoning or data is involved.
#
# Factors that affect speed:
# - Prompt length and complexity
# - Amount of reasoning or data lookup required
# - Server load and routing
# - Your network latency
#
# If you want faster replies, try:
# - Asking for a brief answer or bullet-point summary
# - Breaking complex tasks into smaller parts
# - Being explicit about what you want to prioritize
#
# If you’d like, you can give me a short prompt now and I can give you a quick timing estimate based on the response I generate.
