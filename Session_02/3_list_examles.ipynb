# %%
friuts = ["apples", "banana", "cherry"]
for fruit in friuts:
    print(fruit)
# Out:
# apples
# banana
# cherry

# %%
for char in "Python":
    print(char)
# Out:
# P
# y
# t
# h
# o
# n

# %%
person = {
    "name": 'Alban Ssonko',
    "Age": 32,
    "Adress": "7000 Vassar Ave, Canoga Park"
}

print(person.get("name"))
# Out:
# Alban Ssonko
